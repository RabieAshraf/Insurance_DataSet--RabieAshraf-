# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('insurance-data.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isna().sum().sum() #No nulls
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
sns.barplot(data=df,x='sex', y='charges') #Male has more charges

# %%
sns.barplot(data=df, x='children', y='charges')

# %%
sns.scatterplot(data=df, x='children', y='charges',hue='sex')

# %%
sns.barplot(data=df ,x='smoker', y='charges' ) #Smoker has way moreee charges

# %%
sns.lineplot(data=df, x='age', y='charges') # As age increase , charges increases

# %%
sns.scatterplot(data=df, x='age', y='charges', hue='sex')

# %%
sns.barplot(data=df, x='region', y='charges') #Southeast has the most charges

# %%
sns.lineplot(data=df, x='bmi', y='charges')

# %%
sns.scatterplot(data=df, x='bmi', y='charges', hue='sex')

# %%
male_no = df['sex'].value_counts()['male']
male_no
# Out:
# 676

# %%
female_no = df['sex'].value_counts()['female']
female_no
# Out:
# 662

# %%
plt.pie([male_no,female_no], labels=['male','female'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd3cf9966d0>,
# ...
#  [Text(-0.018078568997004985, 1.0998514287589123, 'male'),
#   Text(0.018078568997005343, -1.0998514287589123, 'female')],
#  [Text(-0.009861037634729992, 0.5999189611412249, '50.5%'),
#   Text(0.009861037634730185, -0.5999189611412248, '49.5%')])

# %%
df_male = df.loc[df['sex']=='male']
df_male
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [676 rows x 7 columns]

# %%
df_female = df.loc[df['sex'] == 'female']
df_female
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
smoke_men = df_male['smoker'].value_counts()['yes']
smoke_men
# Out:
# 159

# %%
smoke_fem = df_female['smoker'].value_counts()['yes']
smoke_fem
# Out:
# 115

# %%
plt.pie([smoke_men,smoke_fem], labels=['men','women'], autopct='%1.1f%%') #Men smoke more than women
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd3cf971810>,
# ...
#  [Text(-0.2745360928198315, 1.0651900927718119, 'men'),
#   Text(0.2745361925501242, -1.065190067067883, 'women')],
#  [Text(-0.14974695971990806, 0.5810127778755336, '58.0%'),
#   Text(0.14974701411824953, -0.581012763855209, '42.0%')])

# %%
#compare smokers and bmi
sns.barplot(data=df, x='smoker', y='bmi') #Same value

# %%
#We can conclude from these data the following
#Men had more charges than women -> may aim for more men to get more charges
#Smokers had very high charges
#The southeast region had most charges
#Children didn't play an important role in charges
#Bmi didn't have a high effect in charges
